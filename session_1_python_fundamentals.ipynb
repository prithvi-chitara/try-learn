# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvi-chitara/try-learn/blob/main/session_1_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# # python fundamentals dsmp session 1    (video no 11)

# %%
# 1 print Output Function

# %%
print("try","fry",sep="-")
# Out:
# try-fry

# %%
print("try",end="  ")
print("fry")
# Out:
# try  fry

# %%
print(1)
# Out:
# 1

# %%
print(1.1)
# Out:
# 1.1

# %%
print(True)
# Out:
# True

# %%
print(2+3j)
# Out:
# (2+3j)

# %%
print("try",True,1.0,1)
# Out:
# try True 1.0 1

# %%
# 2 Data Types

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
# integer

# %%
print(1e309)  # 1*10**309
# Out:
# inf

# %%
# decimal/ float

# %%
print(1.1)
# Out:
# 1.1

# %%
print(1e309)
# Out:
# inf

# %%
# text/ string

# %%
print("fry")
# Out:
# fry

# %%
# complex

# %%
print(2+3j)
# Out:
# (2+3j)

# %%
# list ---> c -->array  []  mutable

# %%
print([1,True,1.1,"try"])
# Out:
# [1, True, 1.1, 'try']

# %%
# Tuple  ()   imutable

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Set {}

# %%
print({1,True,1.1,1.0,"try"})  # here 1 , 1.0, True sbke liye 1 duplicate not allow
# Out:
# {1, 'try', 1.1}

# %%
# Dict {}   key pair vales'

# %%
print({1:"try",2:2,3:True,"one":1})
# Out:
# {1: 'try', 2: 2, 3: True, 'one': 1}

# %%
type(2)
# Out:
# int

# %%
type(3.5)
# Out:
# float

# %%
type("try")
# Out:
# str

# %%
type([1,2,3])
# Out:
# list

# %%
# Variables
''' temperory storage space
Static vs dynamic'''
# Out:
# ' temperory storage space \nStatic vs dynamic'

# %%
name = "Prithvi"   # here name = variable , assisgnment opertor(=)  , Prithvi is value of variable

# %%
a=5    # here
b=7
print(a+b)
# Out:
# 12

# %%
# Dynamic typing a=5  automatically detect it is integer
# c , c++ , java static programing

# %%
a = 5
v = "try"
a = 7
print(a)
print(v)
print(a)
# Out:
# 7
# try
# 7

# %%
a = 5
b = 3
c = 5
print(a,b,c)
# Out:
# 5 3 5

# %%
a=b=c=5

# %%
print(a,b,c,sep="-")
# Out:
# 5-5-5

# %%
#  this is a comments

print('''this multiline
comments here

liny by line''')
# Out:
# this multiline
# comments here
#
# liny by line

# %%
# 4 Keywords and identifiers

# %%
# keywords -  predefine words (reserve word)
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# identifier   - lower caes ,upper case,  no start with number, special character not use for define variabe

# %%
_a=5

# %%
print(_a)
# Out:
# 5

# %%
1a=5   # wrong
# Out:
#   File "/tmp/ipykernel_485/4103205483.py", line 1
#     1a=5   # wrong
#     ^
# SyntaxError: invalid decimal literal

# %%
t5=1   # right

# %%
t_1=7

# %%
print(t_1)
# Out:
# 7

# %%
CASE = "TRY"

# %%
print(CASE)
# Out:
# TRY

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_485/52251157.py in <cell line: 0>()
# ----> 1 a@=5
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
# User input

# %%
input()
# Out:
# 4
# '4'

# %%
input("enter  your name: ")
# Out:
# enter  your name: prithvi
# 'prithvi'

# %%
input("enter your email:")
# Out:
# enter your email:chitaraprithvi@gmail.com
# 'chitaraprithvi@gmail.com'

# %%
# two variable sum

# %%
a=input("enter 1st number:")
b=input("enter 2nd number:")
c = int(a)+int(b)
print("sum is ",c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# enter 1st number:7
# enter 2nd number:7
# sum is  14
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
55

# %%
 # 6 type conersaion

# %%
print(5+5.6)   # implicit
# Out:
# 10.6

# %%
print(type(5),type(5.6))
# Out:
# <class 'int'> <class 'float'>

# %%
# explicit
print(int("5"))
# Out:
# 5

# %%
float(4)
# Out:
# 4.0

# %%
str(5)
# Out:
# '5'

# %%
# 7 Literals

# %%
a = 2    # here a is variable, = operator, 2 is value

# %%
a = 0b1010 # binary

# %%
a
# Out:
# 10

# %%
b = 100 # decimal

# %%
c = 0o310   # octal

# %%
c
# Out:
# 200

# %%
d = 0x12c # hexadecimal

# %%
d
# Out:
# 300

# %%
print(hex(300))
# Out:
# 0x12c

# %%
oct(200)
# Out:
# '0o310'

# %%
# float literals

# %%
f1 = 10.5
f2 = 1.5e2
f3 = 1.5e-3

# %%
f1
# Out:
# 10.5

# %%
f2
# Out:
# 150.0

# %%
f3
# Out:
# 0.0015

# %%
# complex literals

# %%
x = 3+4j

# %%
x.imag
# Out:
# 4.0

# %%
x.real
# Out:
# 3.0

# %%
a = True+4

# %%
a
# Out:
# 5

# %%
b = False+4

# %%
b
# Out:
# 4

# %%
a = None

# %%
print(a)
# Out:
# None

# %%
a=None
b = 3
c = 5
print(b+c)
# Out:
# 8

# %%
# 8 Operators
# arithmetic  +,-,*,/
# relational  and , or
#logical > , >= , <, <=
# bitwise
# assignment =,
# membership in , not in
